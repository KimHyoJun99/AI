# %%
my_list = [10, "hello list", 20]
print(my_list[1])
# Out:
# hello list

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.19.5

# %%
my_arr = np.array([[10, 20, 30], [40, 50, 60]])
print(my_arr)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
type(my_arr)
# Out:
# numpy.ndarray
